# %%
import requests
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import re
import time
import urllib.parse
import random

# %% [markdown]
# # 1. Set up Selenium

# %%
url = "https://minibardelivery.com/store/search/organic%2Bwine?q=organic%2520wine"
driver = webdriver.Chrome("//Users/irene/CloudStation/Courses/Digital Technologies and Value Creation/Group Project/US/Group 3/Codes/Data scraping/chromedriver")
driver.get(url)
# Out:
# /var/folders/65/l8gwbbg117z6hscwvjl3vg0m0000gn/T/ipykernel_2764/3601399097.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("//Users/irene/CloudStation/Courses/Digital Technologies and Value Creation/Group Project/US/Group 3/Codes/Data scraping/chromedriver")

# %% [markdown]
# ## Scroll down page

# %%
SCROLL_PAUSE_TIME = 4

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %% [markdown]
# # Comebine Selenium & Beautifulsoup

# %%
page_source = driver.page_source
page_source
# Out:
# '<html lang="en"><head><meta charset="utf-8"><meta content="width=device-width,initial-scale=1" name="viewport"><script async="true" src="https://tr.snapchat.com/config/com/73420237-fbd4-40e4-a9d0-99733bfd4b2f.js" crossorigin="anonymous"></script><script async="" src="https://sc-static.net/scevent.min.js"></script><script type="text/javascript" async="" src="https://init.blackcrow.ai/js/core/minibardelivery.js"></script><script type="text/javascript" async="" src="https://static.ads-twitter.com/uwt.js"></script><script async="" src="https://s.pinimg.com/ct/lib/main.9a94ee76.js"></script><script type="text/javascript" async="" src="https://djnf6e5yyirys.cloudfront.net/js/friendbuy.min.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=AW-977599923"></script><script type="text/javascript" async="" src="https://s.pinimg.com/ct/core.js"></script><script type="text/javascript" async="" src="https://cdn.amplitude.com/libs/amplitude-5.2.2-min.gz.js"></script><script src="https://connect.facebook.net/signals/config/860813734045183?v=2.9.90&amp;r=stable" async=""></script><script src="https://connect.facebook.net/signals/plugins/identity.js?v=2.9.90" async=""></script><script type="text/javascript" async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://cdn.quantummetric.com/qscripts/quantum-reservebar.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-WY81EC6MLX&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-T9MSVT"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=UA-42730374-1"></script><script type="text/javascript" async="" src="https://cdn.segment.com/analytics.js/v1/8zLLJzrgE3QHToVLPsJO7iLyNTBmaH8R/analytics.min.js"></script><script type="application/ld+json">{"@context":"https://schema.org","@type":"WebSite","url":"https://minibardelivery.com","potentialAction":[{"@type":"SearchAction","target":"https://minibardelivery.com/store/search/{search_term_string}?q={search_term_string}={search_term_string}","query-input":"required name=search_term_string"}]}</script><title>Minibar Delivery: Get Alcohol Delivered. Organic 2 Bwine</title><meta name="twitter:card" content="app"><meta name="twitter:site" content="@MinibarDelivery"><meta name="twitter:creator" content="@MinibarDelivery"><meta property="fb:app_id" content="251790598309936"><meta property="og:title" content="Minibar Delivery: Get Alcohol Delivered. Organic 2 Bwine"><meta property="og:url" content="https://minibardelivery.com/store/search/organic%2Bwine?q=organic%2520wine"><meta property="og:type" content="website"><meta property="og:image" content="/static/images/socialsharephoto.jpg"><meta property="og:image:alt" content="Shop the Minibar Delivery App for the best selection of wine, liquor, beer, and more - delivered directly to your door in as little as 30 to 60 minutes. Fast delivery and low prices!"><meta property="og:image:width" content="1024"><meta property="og:image:height" content="538"><meta property="og:site_name" content="Minibar Delivery: Get Alcohol Delivered."><link rel="canonical" href="https://minibardelivery.com/store/search/organic%2Bwine?q=organic%2520wine"><meta content="Minibar Delivery: Get Alcohol Delivered." name="twitter:app:name:iphone"><meta content="Minibar Delivery: Get Alcohol Delivered." name="twitter:app:name:ipad"><meta content="720850888" name="twitter:app:id:iphone"><meta content="720850888" name="twitter:app:id:ipad"><meta content="minibar.android" name="twitter:app:id:googleplay"><meta content="US" name="twitter:app:country"><meta content="minibar://minibar/store/search/organic%2Bwine?q=organic%2520wine" property="al:android:url"><meta content= ...

# %%
soup = BeautifulSoup(page_source , "html.parser")
print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <script async="true" crossorigin="anonymous" src="https://tr.snapchat.com/config/com/73420237-fbd4-40e4-a9d0-99733bfd4b2f.js">
#   </script>
#   <script async="" src="https://sc-static.net/scevent.min.js">
#   </script>
#   <script async="" src="https://init.blackcrow.ai/js/core/minibardelivery.js" type="text/javascript">
#   </script>
#   <script async="" src="https://static.ads-twitter.com/uwt.js" type="text/javascript">
#   </script>
#   <script async="" src="https://s.pinimg.com/ct/lib/main.9a94ee76.js">
#   </script>
#   <script async="" src="https://djnf6e5yyirys.cloudfront.net/js/friendbuy.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-977599923" type="text/javascript">
#   </script>
#   <script async="" src="https://s.pinimg.com/ct/core.js" type="text/javascript">
#   </script>
#   <script async="" src="https://cdn.amplitude.com/libs/amplitude-5.2.2-min.gz.js" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/860813734045183?v=2.9.90&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/plugins/identity.js?v=2.9.90">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js" type="text/javascript">
#   </script>
#   <script async="" src="https://cdn.quantummetric.com/qscripts/quantum-reservebar.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-WY81EC6MLX&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-T9MSVT" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-42730374-1" type="text/javascript">
#   </script>
#   <script async="" src="https://cdn.segment.com/analytics.js/v1/8zLLJzrgE3QHToVLPsJO7iLyNTBmaH8R/analytics.min.js" type="text/javascript">
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"WebSite","url":"https://minibardelivery.com","potentialAction":[{"@type":"SearchAction","target":"https://minibardelivery.com/store/search/{search_term_string}?q={search_term_string}={search_term_string}","query-input":"required name=search_term_string"}]}
#   </script>
#   <title>
#    Minibar Delivery: Get Alcohol Delivered. Organic 2 Bwine
#   </title>
#   <meta content="app" name="twitter:card"/>
#   <meta content="@MinibarDelivery" name="twitter:site"/>
#   <meta content="@MinibarDelivery" name="twitter:creator"/>
#   <meta content="251790598309936" property="fb:app_id"/>
#   <meta content="Minibar Delivery: Get Alcohol Delivered. Organic 2 Bwine" property="og:title"/>
#   <meta content="https://minibardelivery.com/store/search/organic%2Bwine?q=organic%2520wine" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="/static/images/socialsharephoto.jpg" property="og:image"/>
#   <meta content="Shop the Minibar Delivery App for the best selection of wine, liquor, beer, and more - delivered directly to your door in as little as 30 to 60 minutes. Fast delivery and low prices!" property="og:image:alt"/>
#   <meta content="1024" property="og:image:width"/>
#   <meta content="538" property="og:image:height"/>
#   <meta content="Minibar Delivery: Get Alcohol Delivered." property="og:site_name"/>
#   <link href="https://minibardelivery.com/store/search/organic%2Bwine?q=organic%2520wine" rel="canonical"/>
#   <meta content="Minibar Delivery: Get Alcohol Delivered." name="twitter:app:name:iphone"/>
#   <meta content="Minibar Delivery: Get Alcohol Delivered." name="twitter:app:name:ipad"/>
#   <meta content="720850888" name="twitter:app:id:iphone"/>
#   <meta content="720850888" name="twitter:app:id:ipad"/>
#   <meta content="minibar.android" name="twitter:app:id:googleplay"/>
#   <meta content="US" name="twitter:app:country"/>
#   <meta content="minibar://minibar/store/search/organic%2Bwine?q=organic%2520wine" property="al:android:url"/>
#   <meta content="Minibar Delivery: Get Alcohol Delivered." property="al:android:app_name"/>
#   <meta content="minibar.android" property="al:android:package"/>
#   <meta content="minibar://minibar/store/search/organic%2Bwine?q=organic%2520wine" property="al:ios:url"/>
#   <meta content="Minibar Delivery: Get Alcohol Delivered." property="al:ios:app_name"/>
#   <meta content="720850888" property="al:ios:app_store_id"/>
#   <link href="/static/icons/favicon.ico" rel="icon"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="Alcohol delivered to your door. Shop Minibar Delivery for the best selection of wine, liquor, beer, and more - available in 30 to 60 minutes. Fast delivery and low prices!" name="description"/>
#   <meta content="Alcohol delivered to your door. Shop Minibar Delivery for the best selection of wine, liquor, beer, and more - available in 30 to 60 minutes. Fast delivery and low prices!" property="og:description"/>
#   <meta content="Alcohol delivered to your door. Shop Minibar Delivery for the best selection of wine, liquor, beer, and more - available in 30 to 60 minutes. Fast delivery and low prices!" name="twitter:description"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="34" name="next-head-count"/>
#   <link as="style" crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/8ae8e7913d356be4.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-g="" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/8ae8e7913d356be4.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/1ab3e18737b50ec8.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/1ab3e18737b50ec8.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/62ce85b5b732ee24.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/62ce85b5b732ee24.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/6527f7cde01ad450.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/6527f7cde01ad450.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/78af84a32dab9d04.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/78af84a32dab9d04.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/ad1cae516ba13517.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/ad1cae516ba13517.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/eebbab41ed4bd7e5.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/eebbab41ed4bd7e5.css" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/94c0f789037b2dff.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-p="" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/94c0f789037b2dff.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script crossorigin="anonymous" defer="" nomodule="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/webpack-1ac4293b4c621a31.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/framework-830029a1de17d4bb.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/main-4fceb09e7492fc19.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/pages/_app-887ca17541e6d2bf.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/6896-c4cf48bb366d73ce.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/7763-86d210857721dfeb.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/9507-d692c36be0fdf10e.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/9733-eefa6dac1614496f.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/1153-f09bb3a38335bee1.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/8081-2d3f2ebe23aa3974.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/3200-1565a5d043efd2b1.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/5809-21750cef952f99b3.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/1717-4e73c5eaccc77188.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/5865-ee1ad590346990f0.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/2416-dd2deee4db304d95.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/2306-a3e6dc199a6e7d67.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/3231-fbc8b0f185247bc6.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/chunks/pages/store/search/%5Bterm%5D-65e4947d1bd85e5a.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/414d92759e14238a73d7b8f61ea13bf4/_buildManifest.js">
#   </script>
#   <script crossorigin="anonymous" defer="" src="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/414d92759e14238a73d7b8f61ea13bf4/_ssgManifest.js">
#   </script>
#   <style type="text/css">
#    .styles_snaplist__3CnrO {
#   flex: 1;
# }
#
# .styles_snaplist_hide_scrollbar__3B0vy {
#   scrollbar-width: none;
#   -ms-overflow-style: none;
# }
#
# .styles_snaplist_hide_scrollbar__3B0vy::-webkit-scrollbar {
#   display: none;
# }
#
# .styles_snaplist_horizontal__sje6U {
#   display: flex;
#   flex-direction: row;
#   max-width: 100%;
# }
#
# .styles_snaplist_vertical__GAU9F {
#   max-height: 100%;
# }
#
# .styles_snaplist_active_horizontal__1AcsB {
#   scroll-snap-type: x mandatory;
# }
#
# .styles_snaplist_active_vertical__3nO4X {
#   scroll-snap-type: y mandatory;
# }
#
# .styles_snaplist_scroll_disabled__18IPq {
#   overflow-y: hidden;
#   overflow-x: hidden;
# }
#
# .styles_snaplist_scroll_horizontal__3Wsh1 {
#   overflow-y: hidden;
#   overflow-x: auto;
# }
#
# .styles_snaplist_scroll_vertical__2D_zA {
#   overflow-y: auto;
#   overflow-x: hidden;
# }
#
# .styles_snapitem__MTDDf {
#   flex: 1;
#   display: flex;
#   flex-grow: initial;
#   flex-shrink: 0;
#   flex-basis: auto;
# }
#
# .styles_snaplist__3CnrO::after {
#   content: '';
#   flex: 0 0 1px;
# }
#
# .styles_snapitem_align_center__1jM9V {
#   scroll-snap-align: center;
# }
#
# .styles_snapitem_align_start__3zzUa {
#   scroll-snap-align: start;
# }
#
# .styles_snapitem_align_end__2efEU {
#   scroll-snap-align: end;
# }
#
# .styles_snapitem_align_none__32nWH {
#   scroll-snap-align: none;
# }
#
# .styles_snapitem_forcestop__1ycfI {
#   scroll-snap-stop: always;
# }
#   </style>
#   <style type="text/css">
#    .stylesdrag_snaplist_drag__1lMGg {
#   scroll-snap-type: none;
# }
#
# .stylesdrag_snaplist_drag__1lMGg * {
#   user-select: none;
# }
#   </style>
#   <link crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/cbf63e072f82f926.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://cdn.minibardelivery.com/_next/414d92759e14238a73d7b8f61ea13bf4/_next/static/css/4da7241893c44a24.css" rel="stylesheet" type="text/css"/>
#   <link href="data:text/css;charset=utf-8;base64,..." rel="stylesheet"/>
#   <script async="" src="https://tag.wknd.ai/4214/i.js">
#   </script>
#   <script async="" src="https://static.hotjar.com/c/hotjar-2613142.js?sv=6">
#   </script>
#   <style id="kustomer-mobile-style">
#    .kustomer-mobile-active { height: calc(100vh - 1px) }
#     .kustomer-mobile-active > body {position: fixed !important; overflow: hidden !important; }
#     .kustomer-remove-scroll { scroll-behavior: unset !important; }
#   </style>
#   <script async="" charset="utf-8" src="https://script.hotjar.com/modules.352fddba5b21bbfc3a08.js">
#   </script>
#   <style type="text/css">
#    iframe#_hjRemoteVarsFrame {display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;}
#   </style>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/977599923/?random=1671970564194&amp;cv=11&amp;fst=1671970564194&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=2oabu0&amp;u_w=1440&amp;u_h=900&amp;hn=www.googleadservices.com&amp;frm=0&amp;url=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine&amp;tiba=Minibar%20Delivery%3A%20Get%20Alcohol%20Delivered.%20Organic%202%20Bwine&amp;auid=1387823495.1671970564&amp;uaa=x86&amp;uab=64&amp;uafvl=Not%253FA_Brand%3B8.0.0.0%7CChromium%3B108.0.5359.124%7CGoogle%2520Chrome%3B108.0.5359.124&amp;uap=macOS&amp;uapv=12.6.1&amp;uaw=0&amp;data=event%3Dgtag.config&amp;rfmt=3&amp;fmt=4" type="text/javascript">
#   </script>
#   <script async="" src="//assets.bounceexchange.com/assets/smart-tag/versioned/inbox_dbcafa82ba21334528d547ee82a14869.br.js" type="text/javascript">
#   </script>
#   <script async="" src="//assets.bounceexchange.com/assets/smart-tag/versioned/onsite_d77202ee63f46daf80998ccf300f48a4.br.js" type="text/javascript">
#   </script>
#   <script async="" src="https://assets.bounceexchange.com/assets/bounce/jquery-3.5.1.min.js">
#   </script>
#   <meta content="A6tVmVPNv7ei4ErCylDEwnE6N9RJTv0xr0vkb/AAsDo1pT2LYjQVGXq5JSDAHLx7TB8jjHfD2e8qlu3dZMP+ew8AAABveyJvcmlnaW4iOiJodHRwczovL3MucGluaW1nLmNvbTo0NDMiLCJmZWF0dXJlIjoiUHJpdmFjeVNhbmRib3hBZHNBUElzIiwiZXhwaXJ5IjoxNjY5NzY2Mzk5LCJpc1RoaXJkUGFydHkiOnRydWV9" http-equiv="origin-trial"/>
#   <script async="async" src="https://api.bounceexchange.com/bounce/init1.js?wklzs=1027&amp;wklz=C4ewVgigvAZgrgOwMbAJYgQMhQZygRgDYB2fATmIAYBWQgFlICZNgAvEKSzAdwFMAjHKmC8A+qgAmUOo3x1MAJ144QAGzhoMBRpUoAPKsUW8YvBUoVRsAQ1WrUCAOai4C1VAAWwYAAccAUgBmAEF-RgAxMPCAWwdUfmsFCV57ADczAE8AOiQQaKicUCUC3kSkDyiQBUdrBFQkMOpGACFuB14g8IBHIIARKpq6hsYmpso2hF5MVNQhYFFckABrVF4of2JmsMZVH22g0MZGL18AkZDGiMuYuISklNR0hWzc-JGIwqqO9-CcUoVytcBrV6pcmq12o1At0of1qiDhqN3uNIUcwgBhbYKfYXNF4zFHXh6HHBIikCiMQL0QjkDa9bAgZardabbapEkbLaEp6iVQgRyOXgScQIEkwWx--hQhrNFX9vTxOMpysIIjCsqvpbouAHnvqkHvtBV7mpa0TWpuUB2g6d4Xm6cF-Hevr+lmQq4VM0GRtGsYzgmJF3uRGaUQsuZLMRb54dB64zgg5a8JWqDVix-5jveLboO2nYpD2oHxn6NGpMkMAwS64nALJ8njgRlECVBal0ZmcYEapJjjrpDE5tGWnwWpHEitxvH8RIhkKc2q6iR2XaSX2MmsVMiwrGIoAgLyiSCt5mD8D4nCYLwvhQOOABEe5xQANAl1giI4VQZMlCUeD2SxtsA2UeHkvDZZ+cAoNlfxlB4cWzpgPjAHg1UAh4DLRD49i1EgYgwKo1iOFYqQeNYUBAA" type="text/javascript">
#   </script>
#   <script async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/977599923/?random=1671970565831&amp;cv=11&amp;fst=1671970565831&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=2oabu0&amp;u_w=1440&amp;u_h=900&amp;hn=www.googleadservices.com&amp;frm=0&amp;url=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine&amp;tiba=Minibar%20Delivery%3A%20Get%20Alcohol%20Delivered.%20Organic%202%20Bwine&amp;auid=1387823495.1671970564&amp;uaa=x86&amp;uab=64&amp;uafvl=Not%253FA_Brand%3B8.0.0.0%7CChromium%3B108.0.5359.124%7CGoogle%2520Chrome%3B108.0.5359.124&amp;uap=macOS&amp;uapv=12.6.1&amp;uaw=0&amp;data=event%3Dform_start&amp;rfmt=3&amp;fmt=4" type="text/javascript">
#   </script>
#   <script async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/977599923/?random=1671970565858&amp;cv=11&amp;fst=1671970565858&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=2oabu0&amp;u_w=1440&amp;u_h=900&amp;hn=www.googleadservices.com&amp;frm=0&amp;url=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine&amp;tiba=Minibar%20Delivery%3A%20Get%20Alcohol%20Delivered.%20Organic%202%20Bwine&amp;auid=1387823495.1671970564&amp;uaa=x86&amp;uab=64&amp;uafvl=Not%253FA_Brand%3B8.0.0.0%7CChromium%3B108.0.5359.124%7CGoogle%2520Chrome%3B108.0.5359.124&amp;uap=macOS&amp;uapv=12.6.1&amp;uaw=0&amp;data=event%3Dform_submit&amp;rfmt=3&amp;fmt=4" type="text/javascript">
#   </script>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/647313210/?random=1671970566873&amp;cv=11&amp;fst=1671970566873&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=2wgbu0&amp;u_w=1440&amp;u_h=900&amp;hn=www.googleadservices.com&amp;frm=0&amp;url=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine&amp;tiba=Minibar%20Delivery%3A%20Get%20Alcohol%20Delivered.%20Organic%202%20Bwine&amp;auid=1387823495.1671970564&amp;uaa=x86&amp;uab=64&amp;uafvl=Not%253FA_Brand%3B8.0.0.0%7CChromium%3B108.0.5359.124%7CGoogle%2520Chrome%3B108.0.5359.124&amp;uap=macOS&amp;uapv=12.6.1&amp;uaw=0&amp;rfmt=3&amp;fmt=4" type="text/javascript">
#   </script>
#  </head>
#  <body class="" data-cf-browser-name="chrome" data-cf-browser-state="modern" data-cf-browser-version="108">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/gtm.js?id=GTM-T9MSVT" width="0">
#    </iframe>
#   </noscript>
#   <div data-reactroot="" id="__next">
#    <div>
#     <div>
#      <header>
#       <div class="TopBanner_element__F5ki8">
#        <p style="margin: 0px; font-stretch: normal; font-size: 13px; line-height: normal; font-family: 'Helvetica Neue';">
#         <span style="font-family: Avenir, Avenir-Local, 'Helvetica Neue', Helvetica, Arial, sans-serif;">
#          Wine, liquor, beer, and more delivered right to your door.
#         </span>
#        </p>
#        <script>
#        </script>
#       </div>
#       <hr class="HeaderBar_externalHr__ekl1z"/>
#       <div class="HeaderBar_wrapper__NFDF7">
#        <div class="HeaderBar_header___c_Xj">
#         <div class="HeaderBar_logo___XURR">
#          <h2 class="MinibarLogo_element__aOQSq">
#           <button class="MinibarLogo_logo__s6aM0" title="Minibar Delivery" type="button">
#            Minibar Delivery
#           </button>
#          </h2>
#         </div>
#         <div class="HeaderBar_hideOnMobile__vS1IS">
#          <div class="HeaderBar_address__TlMIt">
#           <button class="AddressToggle_button__XAEX8 AddressToggle_buttonSelected__2rHjg AddressToggle_onDemandPickupShipped__4K0zO" id="address-toggle-button" type="button">
#            <span class="AddressToggle_container__PgWeD">
#             <span class="AddressToggle_title__9uUWB">
#              Delivery, pickup and shipping
#             </span>
#             <span class="AddressToggle_address__y3IRP">
#              Add delivery address
#             </span>
#            </span>
#           </button>
#          </div>
#          <div class="HeaderBar_giftCards__tIt53">
#           <button class="GiftCardButton_element__2ymcz" type="button">
#            <svg fill="none" height="21" viewbox="0 0 19 21" width="19" xmlns="http://www.w3.org/2000/svg">
#             <path d="M17.5942 13.6853L12.3766 1.98489C11.8874 0.887978 10.6035 0.395979 9.50656 0.885129L1.98487 4.2393C0.887951 4.72845 0.395952 6.01241 0.885102 7.10932L6.1027 18.8097C6.59185 19.9067 7.87581 20.3987 8.97273 19.9095L16.4944 16.5553C17.5913 16.0662 18.0833 14.7822 17.5942 13.6853ZM8.50687 18.8648C7.98975 19.0954 7.37798 18.861 7.14738 18.3439L1.92978 6.64347C1.69918 6.12635 1.93361 5.51458 2.45072 5.28398L9.97242 1.92981C10.4895 1.69921 11.1013 1.93363 11.3319 2.45075L16.5495 14.1512C16.7801 14.6683 16.5457 15.2801 16.0286 15.5107L8.50687 18.8648Z" fill="black">
#             </path>
#            </svg>
#            Gift Cards
#           </button>
#          </div>
#          <div class="HeaderBar_giftGuide__RRBiU">
#           <button class="GiftCardButton_giftGuideButton__bCcLQ" type="button">
#            <svg fill="none" height="23" viewbox="0 0 23 23" width="23" xmlns="http://www.w3.org/2000/svg">
#             <path d="M2.13478 8.68798V19.5392C2.13477 19.8547 2.19703 20.1671 2.31799 20.4585C2.43894 20.7499 2.61621 21.0145 2.83963 21.2373C3.06305 21.46 3.32824 21.6365 3.61999 21.7566C3.91174 21.8767 4.22433 21.938 4.53982 21.9371H18.2372C18.8732 21.9371 19.4831 21.6845 19.9328 21.2348C20.3825 20.7851 20.6351 20.1751 20.6351 19.5392V8.68798C20.6352 8.05136 20.3827 7.4407 19.9332 6.98987C19.4837 6.53904 18.8738 6.28482 18.2372 6.28294H16.7145C16.9245 6.06635 17.1106 5.82779 17.2695 5.57138C17.5738 5.06182 17.7415 4.48239 17.7565 3.88909C17.7714 3.29578 17.6331 2.70864 17.3549 2.18439C17.1129 1.76178 16.7607 1.4128 16.3358 1.1747C15.911 0.936593 15.4295 0.818301 14.9427 0.832441C14.4096 0.815448 13.8791 0.91414 13.3878 1.12173C12.8965 1.32932 12.4559 1.64087 12.0965 2.03497C11.8122 2.33598 11.5726 2.67625 11.385 3.04537C11.2083 2.67843 10.9807 2.33827 10.709 2.03497C10.3496 1.64087 9.90902 1.32932 9.41769 1.12173C8.92636 0.91414 8.39589 0.815448 7.86278 0.832441C7.37577 0.817837 6.89386 0.935095 6.46801 1.17182C6.04215 1.40855 5.68817 1.75594 5.4435 2.17728C5.16529 2.70152 5.02698 3.28866 5.04194 3.88197C5.05689 4.47528 5.22461 5.0547 5.52888 5.56427C5.68783 5.82067 5.8739 6.05923 6.08389 6.27582H4.53982C4.22339 6.27582 3.91006 6.33826 3.61781 6.45957C3.32555 6.58088 3.0601 6.75867 2.83668 6.98276C2.61326 7.20684 2.43625 7.47281 2.3158 7.76543C2.19536 8.05804 2.13384 8.37155 2.13478 8.68798ZM19.212 8.68798V19.5392C19.212 19.6672 19.1868 19.7939 19.1378 19.9122C19.0889 20.0305 19.017 20.1379 18.9265 20.2285C18.836 20.319 18.7285 20.3908 18.6103 20.4398C18.492 20.4888 18.3652 20.514 18.2372 20.514H12.0965L12.1463 7.70604H18.2586C18.514 7.71345 18.7565 7.82016 18.9346 8.00352C19.1126 8.18687 19.2122 8.43241 19.212 8.68798ZM14.9427 2.28401C15.1802 2.26801 15.4174 2.31885 15.6274 2.43078C15.8374 2.54272 16.0119 2.71125 16.131 2.91729C16.2874 3.22449 16.3612 3.56714 16.345 3.91149C16.3287 4.25584 16.2231 4.59004 16.0385 4.88118C15.7326 5.41484 14.9285 6.30428 12.9931 6.30428H12.0965C12.0965 5.4433 12.2602 3.91346 13.0856 3.00979C13.3194 2.75361 13.6074 2.55293 13.9288 2.42243C14.2501 2.29193 14.5965 2.23491 14.9427 2.25555V2.28401ZM6.73852 4.85271C6.55392 4.56157 6.44831 4.22738 6.43209 3.88303C6.41587 3.53867 6.4896 3.19603 6.64602 2.88883C6.7646 2.68393 6.93794 2.51613 7.14658 2.40427C7.35522 2.2924 7.59091 2.2409 7.8272 2.25555C8.16427 2.23485 8.50181 2.28778 8.81637 2.41066C9.13093 2.53353 9.41498 2.72341 9.64877 2.9671C10.4813 3.89212 10.6307 5.42196 10.6734 6.28294H9.78397C7.8272 6.28294 7.04449 5.38638 6.73852 4.85271ZM3.55788 8.68798C3.55788 8.42756 3.66134 8.1778 3.84549 7.99365C4.02964 7.8095 4.2794 7.70604 4.53982 7.70604H10.6734L10.6236 20.514H4.53982C4.41121 20.5149 4.28368 20.4904 4.16459 20.4418C4.04549 20.3933 3.93719 20.3216 3.84591 20.231C3.75464 20.1404 3.68219 20.0326 3.63276 19.9139C3.58333 19.7951 3.55788 19.6678 3.55788 19.5392V8.68798Z" fill="black">
#             </path>
#            </svg>
#            Gift Guide
#           </button>
#          </div>
#         </div>
#         <div class="HeaderBar_account__MQMPU">
#          <button class="AccountToggle_account__6j0av" title="Menu" type="button">
#           Account
#          </button>
#         </div>
#         <div class="HeaderBar_cart__coosr">
#          <div class="CartView_element__q2vRa">
#           <button aria-label="Cart" class="CartToggle_cart__rwfW9 CartToggle_disabled__Fj_L3" title="Cart" type="button">
#            <div class="CartIcon_element__N9ZsQ">
#             <svg version="1" viewbox="0 0 120 120" xmlns="http://www.w3.org/2000/svg">
#              <g stroke="rgba(0,0,0,.6)" stroke-linecap="round" stroke-linejoin="round" stroke-width="6">
#               <g fill="none">
#                <circle cx="50" cy="99" r="7">
#                </circle>
#                <circle cx="89" cy="99" r="7">
#                </circle>
#                <path d="M30 28h78l-6 34-60 4">
#                </path>
#               </g>
#               <path d="M12 14h14l18 66h52" fill="none">
#               </path>
#              </g>
#             </svg>
#            </div>
#           </button>
#          </div>
#         </div>
#         <hr class="HeaderBar_internalHr__k7i7O"/>
#         <div class="HeaderBar_browse__xGMMX">
#          <nav>
#           <button aria-label="Categories" class="BrowseBar_nav__U0XC_" type="button">
#            <ul class="BrowseBar_menubar__nXqxD" role="menubar">
#             <li class="BrowseBar_category__B8Pyv" role="menuitem">
#              <h3 class="BrowseBar_title__J6xvP">
#               <a aria-disabled="false" aria-haspopup="true" class="BrowseBar_dynamicLink__AEcsb BrowseBar_link__Av6Fq BrowseBar_wine__Bjl7m" href="/store/category/wine" type="button">
#                <div class="">
#                 Wine
#                </div>
#               </a>
#              </h3>
#              <ul class="MenuDropdown_menu__3I0qO" role="menu">
#               <li class="MenuDropdown_submenu__zZFt0" role="presentation">
#                <div class="MenuLinks_content__Lmu0n">
#                 <h4 class="MenuLinks_title__GjvN2">
#                  Categories
#                 </h4>
#                 <div class="MenuLinks_container__eIT8j">
#                  <ul aria-label="Categories" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine/wine-white" role="menuitem">
#                     White
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine/wine-red" role="menuitem">
#                     Red
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine/wine-rose" role="menuitem">
#                     Rose
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine/wine-sparkling" role="menuitem">
#                     Champagne &amp;
#                     <br/>
#                     Sparkling
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine/wine-dessert" role="menuitem">
#                     Dessert
#                    </a>
#                   </li>
#                  </ul>
#                  <ul aria-label="Categories" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine/wine-sake" role="menuitem">
#                     Sake
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine/wine-fortified" role="menuitem">
#                     Fortified
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine/wine-mead" role="menuitem">
#                     Mead
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine/wine-spritzer" role="menuitem">
#                     Spritzer
#                    </a>
#                   </li>
#                   <li class="MenuLink_itemHighlight__5eirH" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/wine" role="menuitem">
#                     Shop All
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#                <div class="MenuLinks_content__Lmu0n">
#                 <h4 class="MenuLinks_title__GjvN2">
#                  Features
#                 </h4>
#                 <div class="MenuLinks_container__eIT8j">
#                  <ul aria-label="Features" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/promos/vineyard-select" role="menuitem">
#                     Vineyard Select
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/content/gift-guide" role="menuitem">
#                     Gift Guide
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/spirited-change-initiative" role="menuitem">
#                     Spirited Change Initiative
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </li>
#              </ul>
#             </li>
#             <li class="BrowseBar_category__B8Pyv" role="menuitem">
#              <h3 class="BrowseBar_title__J6xvP">
#               <a aria-disabled="false" aria-haspopup="true" class="BrowseBar_dynamicLink__AEcsb BrowseBar_link__Av6Fq BrowseBar_liquor__M6Tlh" href="/store/category/liquor" type="button">
#                <div class="">
#                 Liquor
#                </div>
#               </a>
#              </h3>
#              <ul class="MenuDropdown_menu__3I0qO" role="menu">
#               <li class="MenuDropdown_submenu__zZFt0" role="presentation">
#                <div class="MenuLinks_content__Lmu0n">
#                 <h4 class="MenuLinks_title__GjvN2">
#                  Categories
#                 </h4>
#                 <div class="MenuLinks_container__eIT8j">
#                  <ul aria-label="Categories" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-vodka" role="menuitem">
#                     Vodka
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-whiskey" role="menuitem">
#                     Whiskey
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-scotch" role="menuitem">
#                     Scotch
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-tequila" role="menuitem">
#                     Tequila
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-rum" role="menuitem">
#                     Rum
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-gin" role="menuitem">
#                     Gin
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-brandy" role="menuitem">
#                     Brandy
#                    </a>
#                   </li>
#                  </ul>
#                  <ul aria-label="Categories" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-vermouth" role="menuitem">
#                     Vermouth
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-other-liquors" role="menuitem">
#                     Other Liquors
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-mezcal" role="menuitem">
#                     Mezcal
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-ready-to-drink" role="menuitem">
#                     Ready To Drink
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor/liquor-cocktails" role="menuitem">
#                     Cocktails
#                    </a>
#                   </li>
#                   <li class="MenuLink_itemHighlight__5eirH" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/liquor" role="menuitem">
#                     Shop All
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#                <div class="MenuLinks_content__Lmu0n">
#                 <h4 class="MenuLinks_title__GjvN2">
#                  Features
#                 </h4>
#                 <div class="MenuLinks_container__eIT8j">
#                  <ul aria-label="Features" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/promos/party-essentials" role="menuitem">
#                     Party Essentials
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/promos/topshelf" role="menuitem">
#                     Top Shelf Liquor
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/spirited-change-initiative" role="menuitem">
#                     Spirited Change Initiative
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/promos/whiskey-worth-knowing" role="menuitem">
#                     Whiskey Worth Knowing
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </li>
#              </ul>
#             </li>
#             <li class="BrowseBar_category__B8Pyv" role="menuitem">
#              <h3 class="BrowseBar_title__J6xvP">
#               <a aria-disabled="false" aria-haspopup="true" class="BrowseBar_dynamicLink__AEcsb BrowseBar_link__Av6Fq BrowseBar_beer__wXFjM" href="/store/category/beer" type="button">
#                <div class="">
#                 Beer
#                </div>
#               </a>
#              </h3>
#              <ul class="MenuDropdown_menu__3I0qO" role="menu">
#               <li class="MenuDropdown_submenu__zZFt0" role="presentation">
#                <div class="MenuLinks_content__Lmu0n">
#                 <h4 class="MenuLinks_title__GjvN2">
#                  Categories
#                 </h4>
#                 <div class="MenuLinks_container__eIT8j">
#                  <ul aria-label="Categories" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/beer/beer-domestic" role="menuitem">
#                     Domestic
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/beer/beer-imported" role="menuitem">
#                     Imported
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/beer/beer-cider" role="menuitem">
#                     Cider
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/beer/beer-hard-seltzer" role="menuitem">
#                     Hard Seltzer
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/beer/beer-flavored" role="menuitem">
#                     Flavored
#                    </a>
#                   </li>
#                  </ul>
#                  <ul aria-label="Categories" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/beer/beer-hard-tea" role="menuitem">
#                     Hard Tea
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/beer/beer-kegs" role="menuitem">
#                     Kegs
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/beer/beer-non-alcoholic" role="menuitem">
#                     Non Alcoholic
#                    </a>
#                   </li>
#                   <li class="MenuLink_itemHighlight__5eirH" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/beer" role="menuitem">
#                     Shop All
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#                <div class="MenuLinks_content__Lmu0n">
#                 <h4 class="MenuLinks_title__GjvN2">
#                  Features
#                 </h4>
#                 <div class="MenuLinks_container__eIT8j">
#                  <ul aria-label="Features" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/promos/party-essentials" role="menuitem">
#                     Party Essentials
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/promos/craft-beer" role="menuitem">
#                     Craft Brews
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/spirited-change-initiative" role="menuitem">
#                     Spirited Change Initiative
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </li>
#              </ul>
#             </li>
#             <li class="BrowseBar_category__B8Pyv" role="menuitem">
#              <h3 class="BrowseBar_title__J6xvP">
#               <a aria-disabled="false" aria-haspopup="true" class="BrowseBar_dynamicLink__AEcsb BrowseBar_link__Av6Fq BrowseBar_mixers__Is6aC" href="/store/category/mixers" type="button">
#                <div class="">
#                 Mixers
#                </div>
#               </a>
#              </h3>
#              <ul class="MenuDropdown_menu__3I0qO" role="menu">
#               <li class="MenuDropdown_submenu__zZFt0" role="presentation">
#                <div class="MenuLinks_content__Lmu0n">
#                 <h4 class="MenuLinks_title__GjvN2">
#                  Categories
#                 </h4>
#                 <div class="MenuLinks_container__eIT8j">
#                  <ul aria-label="Categories" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/mixers/mixers-dairy" role="menuitem">
#                     Dairy
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/mixers/mixers-juice" role="menuitem">
#                     Juice
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/mixers/mixers-mixers-and-soda" role="menuitem">
#                     Mixers &amp; Soda
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/mixers/mixers-water" role="menuitem">
#                     Flat &amp; Sparkling Water
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/mixers/mixers-coffee" role="menuitem">
#                     Coffee &amp; Tea
#                    </a>
#                   </li>
#                  </ul>
#                  <ul aria-label="Categories" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/mixers/mixers-energy" role="menuitem">
#                     Energy
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/mixers/mixers-sports-drink" role="menuitem">
#                     Sports Drink
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/mixers/mixers-slurpee" role="menuitem">
#                     Slurpee
#                    </a>
#                   </li>
#                   <li class="MenuLink_itemHighlight__5eirH" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/category/mixers" role="menuitem">
#                     Shop All
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#                <div class="MenuLinks_content__Lmu0n">
#                 <h4 class="MenuLinks_title__GjvN2">
#                  Features
#                 </h4>
#                 <div class="MenuLinks_container__eIT8j">
#                  <ul aria-label="Features" class="MenuLinks_items__bP3Rn" role="menu">
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/promos/party-essentials" role="menuitem">
#                     Party Essentials
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/spirited-change-initiative" role="menuitem">
#                     Spirited Change Initiative
#                    </a>
#                   </li>
#                   <li class="MenuLink_item__15vTf" role="presentation">
#                    <a class="MenuLink_link__3WwWg" href="/store/promos/elyx-boutique" role="menuitem">
# ...
#   </script>
#   <iframe height="1" style="position: absolute; top: 0px; left: 0px; border: none; visibility: hidden;" width="1">
#   </iframe>
#   <div class="MBDrawer_overlay___g_RI MBDrawer_overlayHidden__dXyd6">
#   </div>
#   <div class="MBDrawer_drawer__XmAFH CartDrawerProvider_drawer__kBozM MBDrawer_drawerHidden__XMUgz MBDrawer_positionRight__Moe3w" style="width:300px">
#    <div class="CartDrawer_element__HjqpL">
#     <div class="CartDrawer_row__DtKHD">
#      <div class="CartDrawerHeader_element__GQ2yb">
#       <button class="CartDrawerHeader_closeButton__edG1_" type="button">
#        <svg viewbox="0 0 28 14">
#         <defs>
#         </defs>
#         <path d="M27.6792 6.20081c-.0003-.00034-.0006-.00074-.001-.00107L21.9632.32877c-.4282-.439814-1.1207-.438177-1.5469.003839-.4261.441959-.4245 1.156801.0037 1.596681l3.8371 3.94167H1.09375C.489672 5.87096 0 6.37643 0 6.99999c0 .62357.489672 1.12904 1.09375 1.12904H24.257L20.42 12.0707c-.4281.4399-.4298 1.1547-.0036 1.5967.4262.4421 1.1187.4436 1.5468.0038l5.7151-5.87095c.0003-.00034.0006-.00073.001-.00107.4283-.44134.427-1.1585-.0001-1.59837z" fill="rgba(0,0,0,.4)" fill-rule="nonzero">
#         </path>
#        </svg>
#       </button>
#       <span class="CartDrawerHeader_title__IO2J5">
#        Cart
#       </span>
#       0
#      </div>
#     </div>
#     <div class="CartDrawerContent_cartDrawerContent__q2Gad">
#      <div>
#      </div>
#     </div>
#     <div class="CartDrawer_row__DtKHD">
#      <button class="CheckoutButton_button___os35" href="/store/checkout" type="button">
#       Checkout
#      </button>
#     </div>
#    </div>
#   </div>
#   <div>
#   </div>
#   <div>
#   </div>
#   <div>
#   </div>
#   <div>
#   </div>
#   <div>
#   </div>
#   <script src="https://cdn.sift.com/s.js">
#   </script>
#   <script src="https://cdn.kustomerapp.com/chat-web/release-v0.1.340/widget-api.70a9f3595c763c81b903.js">
#   </script>
#   <iframe id="kustomer-ui-sdk-iframe" role="region" srcdoc="
#         &lt;style&gt;
#   html, body, div, span, applet, object, iframe, h1, h2, h3, h4, h5, h6, p, blockquote, pre, a, abbr, acronym, address, big, cite, code, del, dfn, em, img, ins, kbd, q, s, samp, small, strike, strong, sub, sup, tt, var, b, u, i, center, dl, dt, dd, ol, ul, li, fieldset, form, label, legend, table, caption, tbody, tfoot, thead, tr, th, td, article, aside, canvas, details, embed, figure, figcaption, footer, header, hgroup, menu, nav, output, ruby, section, summary, time, mark, audio, video { margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline; color: inherit }
#   article, aside, details, figcaption, figure, footer, header, hgroup, menu, nav, section { display: block; }
#   body { line-height: 1; }
#   ol, ul { list-style: none; }
#   blockquote, q { quotes: none; }
#   blockquote:before, blockquote:after, q:before, q:after { content: ''; content: none; }
#   table { border-collapse: collapse; border-spacing: 0; }
# &lt;/style&gt;
#         &lt;body class=&quot;align-chat-icon-right&quot; &gt;
#           &lt;div id=&quot;root&quot;&gt;&lt;/div&gt;
#           &lt;base target=&quot;_parent&quot;&gt;
#             &lt;script
#               src=&quot;https://cdn.kustomerapp.com/chat-web/core.js&quot;
#               data-kustomer-api-key=&quot;eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..W9HwSi99OlVdPYmaDTdOjiRJfWn1_ErXiyErKIPOLPU&quot;
#             &gt;
#             &lt;/script&gt;
#             &lt;script
#               async
#               src=&quot;https://cdn.kustomerapp.com/chat-web/release-v0.1.340/widget-main.f77e074bf7290964d8f9.js&quot;&gt;
#             &lt;/script&gt;
#         &lt;/body&gt;" style="display: none; border: 0px; width: 0px; height: 0px; position: fixed; bottom: 20px; right: 20px; z-index: 2147483000;" tabindex="0" title="Kustomer Widget SDK Iframe">
#   </iframe>
#   <script data-kustomer-api-key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..W9HwSi99OlVdPYmaDTdOjiRJfWn1_ErXiyErKIPOLPU" src="https://cdn.kustomerapp.com/chat-web/widget.js">
#   </script>
#   <next-route-announcer>
#    <p aria-live="assertive" id="__next-route-announcer__" role="alert" style="border: 0px; clip: rect(0px, 0px, 0px, 0px); height: 1px; margin: -1px; overflow: hidden; padding: 0px; position: absolute; width: 1px; white-space: nowrap; overflow-wrap: normal;">
#    </p>
#   </next-route-announcer>
#   <script id="" type="text/javascript">
#    (function(a){var b=a.createElement("script");b.src=a.location.protocol+"//tag.wknd.ai/4214/i.js";b.async=!0;a.getElementsByTagName("head")[0].appendChild(b)})(document);
#   </script>
#   <script id="" src="https://cdn.attn.tv/minibar/dtag.js" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    (function(){var a=document.createElement("script");a.type="text/javascript";a.async=1;a.src="https://cdn.quantummetric.com/qscripts/quantum-reservebar.js";var b=document.getElementsByTagName("script")[0];!window.QuantumMetricAPI&&b.parentNode.insertBefore(a,b)})();
#   </script>
#   <div style="display: none; visibility: hidden;">
#    <img border="0" height="1" src="https://data.adxcel-ec2.com/pixel/?ad_log=referer&amp;action=lead&amp;pixid=1c542a50-ae5f-4e92-bce6-cbb41fa8d2ac" width="1"/>
#   </div>
#   <script async="async" src="//assets.bounceexchange.com/assets/smart-tag/versioned/main_e2d6c32b895aee0a3860d165f6afbb7b.br.js">
#   </script>
#   <script async="true" data-apikey="2^HIykD" data-bx="1" data-cb="bouncex.dg.initPostDeviceGraph" data-fire="1" data-gm="1" id="c.js" src="//assets.bounceexchange.com/assets/smart-tag/versioned/cjs_min_62f4846d97d6cffa05fd709123de3ea8.js">
#   </script>
#   <iframe aria-hidden="true" id="_hjSafeContext_47347048" src="about:blank" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;" tabindex="-1" title="_hjSafeContext">
#   </iframe>
#   <script id="" type="text/javascript">
#    (function(){try{window.setTimeout(function(){dataLayer.push({event:"VirtualPageView",virtualPageURL:google_tag_manager["GTM-T9MSVT"].macro(13)})},2E3)}catch(a){}})();
#   </script>
#   <script id="" type="text/javascript">
#    (function(){try{window.setTimeout(function(){dataLayer.push({event:"DelayedWindowLoaded"})},2E3)}catch(a){}})();
#   </script>
#   <iframe aria-hidden="true" id="_hjRemoteVarsFrame" name="_hjRemoteVarsFrame" src="https://vars.hotjar.com/box-5e66f98b4ee957db209dc6f63e3d59dd.html" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;" tabindex="-1" title="_hjRemoteVarsFrame">
#   </iframe>
#   <script id="" type="text/javascript">
#    (function(a,b,e){if(!a.snaptr){var c=a.snaptr=function(){c.handleRequest?c.handleRequest.apply(c,arguments):c.queue.push(arguments)};c.queue=[];var d="script";a=b.createElement(d);a.async=!0;a.src=e;b=b.getElementsByTagName(d)[0];b.parentNode.insertBefore(a,b)}})(window,document,"https://sc-static.net/scevent.min.js");snaptr("init","73420237-fbd4-40e4-a9d0-99733bfd4b2f",{user_hashed_email:""});snaptr("track","PAGE_VIEW");
#   </script>
#   <iframe height="0" src="//6929881.fls.doubleclick.net/activityi;src=6929881;type=count0;cat=aw_al0;ord=1057964543106;gtm=2wgbu0;auiddc=1387823495.1671970564;~oref=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine?" style="display: none; visibility: hidden;" width="0">
#   </iframe>
#   <script id="" src="https://www.tp88trk.com/scripts/sdk/everflow.js
# " type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    (function(){try{var d=google_tag_manager["GTM-T9MSVT"].macro(16),e=0,f=function(a){e++;3<e||fetch("/json-ld?"+a).then(function(b){return b.text()}).then(function(b){try{var g=JSON.parse(b),c=document.createElement("script");c.setAttribute("type","application/ld+json");c.textContent=JSON.stringify(g);document.head.appendChild(c)}catch(h){console.log("Error load JSON-LD",h),f(a)}})};if(d){var k=Object.entries(d).map(function(a){var b=a[0];a=a[1];return"string"===typeof a?b+"\x3d"+encodeURIComponent(a):b+"\x3d"+encodeURIComponent(JSON.stringify(a))}).join("\x26");
# f(k)}}catch(a){}})();
#   </script>
#   <img src="https://tags.w55c.net/rs?id=e44a188ccb294449885e15597a1f4ee3&amp;t=homepage"/>
#   <script src="https://dx.mountain.com/spx?dxver=4.0.0&amp;shaid=32722&amp;tdr=&amp;plh=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine&amp;cb=31653936342450530term=value" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    (function(){var c="4.0.0",h="32722",k="term\x3dvalue";try{var f=""!==top.document.referer?encodeURIComponent(top.document.referrer.substring(0,2048)):""}catch(g){f=null!==document.referrer?document.referrer.toString().substring(0,2048):""}try{var a=window&&window.top&&document.location&&window.top.location===document.location?document.location:window&&window.top&&window.top.location&&""!==window.top.location?window.top.location:document.location}catch(g){a=document.location}try{var d=""!==parent.location.href?
# encodeURIComponent(parent.location.href.toString().substring(0,2048)):""}catch(g){try{d=null!==a?encodeURIComponent(a.toString().substring(0,2048)):""}catch(l){d=""}}var e;a=document.createElement("script");var b=document.getElementsByTagName("script");b=Number(b.length)-1;b=document.getElementsByTagName("script")[b];"undefined"===typeof e&&(e=Math.floor(1E17*Math.random()));c="dx.mountain.com/spx?dxver\x3d"+c+"\x26shaid\x3d"+h+"\x26tdr\x3d"+f+"\x26plh\x3d"+d+"\x26cb\x3d"+e+k;a.type="text/javascript";
# a.src=("https:"===document.location.protocol?"https://":"http://")+c;b.parentNode.insertBefore(a,b)})();
#   </script>
#   <iframe id="snap6904994" src="https://tr.snapchat.com/cm/i?pid=73420237-fbd4-40e4-a9d0-99733bfd4b2f&amp;u_scsid=8d2974f0-063e-4f7f-a745-d8ce07a83583&amp;u_sclid=39c620f7-be26-4d21-8e21-1eed0b1a6eac" style="display: none; position: absolute; overflow: hidden; width: 1px; height: 1px;">
#   </iframe>
#   <script src="https://px.mountain.com/st?ga_tracking_id=UA-42730374-1&amp;ga_client_id=2032688579.1671970563&amp;shpt=Minibar%20Delivery%3A%20Get%20Alcohol%20Delivered.%20Organic%202%20Bwine&amp;ga_info=%7B%22status%22%3A%22OK%22%2C%22ga_tracking_id%22%3A%22UA-42730374-1%22%2C%22ga_client_id%22%3A%222032688579.1671970563%22%2C%22shpt%22%3A%22Minibar%20Delivery%3A%20Get%20Alcohol%20Delivered.%20Organic%202%20Bwine%22%2C%22dcm_cid%22%3A%221671970562.1%22%2C%22dcm_gid%22%3A%22383001856.1671970563%22%2C%22mntnis%22%3A%7B%7D%2C%22execution_workflow%22%3A%7B%22iteration%22%3A2%2C%22shpt%22%3A%22OK%22%2C%22dcm_cid%22%3A%22OK%22%2C%22dcm_gid%22%3A%22OK%22%7D%7D&amp;dcm_cid=1671970562.1&amp;dcm_gid=383001856.1671970563&amp;dxver=4.0.0&amp;shaid=32722&amp;plh=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine&amp;cb=31653936342450530term%3Dvalue&amp;shadditional=sh_conversion%3DSHBLOCK%2Cgoogletagmanager%3Dtrue%2Cga4%3Dtrue&amp;shpc=&amp;shcp=" type="text/javascript">
#   </script>
#   <script src="https://gs.mountain.com/gs" type="text/javascript">
#   </script>
#   <img alt="" border="0" height="1" src="https://match.adsrvr.org/track/cmf/generic?ttd_pid=steelhouse&amp;ttd_tpi=1&amp;ttd_puid=ea583204-844d-11ed-85b7-5500a5195441&amp;gdpr=&amp;gdpr_consent=" style="display: none;" width="1"/>
#   <img alt="" border="0" height="1" src="https://insight.adsrvr.org/track/evnt/?adv=htkakaf&amp;ct=0:7kyvg7i&amp;fmt=3" style="display: none;" width="1"/>
#   <script src="https://px.mountain.com/st?ga_tracking_id=UA-42730374-1&amp;ga_client_id=2032688579.1671970563&amp;shpt=Minibar%20Delivery%3A%20Get%20Alcohol%20Delivered.%20Organic%202%20Bwine&amp;ga_info=%7B%22status%22%3A%22OK%22%2C%22ga_tracking_id%22%3A%22UA-42730374-1%22%2C%22ga_client_id%22%3A%222032688579.1671970563%22%2C%22shpt%22%3A%22Minibar%20Delivery%3A%20Get%20Alcohol%20Delivered.%20Organic%202%20Bwine%22%2C%22dcm_cid%22%3A%221671970562.1%22%2C%22dcm_gid%22%3A%22383001856.1671970563%22%2C%22mntnis%22%3A%7B%7D%2C%22execution_workflow%22%3A%7B%22iteration%22%3A2%2C%22shpt%22%3A%22OK%22%2C%22dcm_cid%22%3A%22OK%22%2C%22dcm_gid%22%3A%22OK%22%7D%7D&amp;dcm_cid=1671970562.1&amp;dcm_gid=383001856.1671970563&amp;dxver=4.0.0&amp;shaid=32722&amp;plh=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine&amp;shadditional=sh_conversion%3DSHBLOCK%2Cgoogletagmanager%3Dtrue%2Cga4%3Dtrue&amp;shpc=&amp;shcp=&amp;cb=1671970569735469&amp;shguid=33c47388-da09-38a4-a331-afb198058456&amp;shgts=1671970570603" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    !function(){var e='(function(){try {window.mntn = {is_viewable_verified_visit:\'false\', is_cross_device:\'false\', creative_group_id:\'\', creative_group_name:\'\', impression_epoch_micros:\'\', visit_tracking:\'\'};} catch (e) {}})();',t=document.createElement('script');t.type='text/javascript',document.createElement('canvas').getContext?t.innerText?t.innerText=e:t.textContent=e:t.text=g,e=document.getElementsByTagName('script'),e=Number(e.length)-1,(e=document.getElementsByTagName('script')[e]).parentNode.insertBefore(t,e)}();
#   </script>
#   <script type="text/javascript">
#    (function(){try {window.mntn = {is_viewable_verified_visit:'false', is_cross_device:'false', creative_group_id:'', creative_group_name:'', impression_epoch_micros:'', visit_tracking:''};} catch (e) {}})();
#   </script>
#   <script id="" type="text/javascript">
#    EF.click({offer_id:EF.urlParameter("oid"),affiliate_id:EF.urlParameter("affid"),sub1:EF.urlParameter("sub1"),sub2:EF.urlParameter("sub2"),sub3:EF.urlParameter("sub3"),sub4:EF.urlParameter("sub4"),sub5:EF.urlParameter("sub5"),uid:EF.urlParameter("uid"),transaction_id:EF.urlParameter("tid")});
#   </script>
#   <img height="1" src="https://t.co/i/adsct?bci=3&amp;eci=2&amp;event_id=50d961c3-9250-4220-81ba-37be457483e8&amp;events=%5B%5B%22pageview%22%2C%7B%7D%5D%5D&amp;integration=advertiser&amp;p_id=Twitter&amp;p_user_id=0&amp;pl_id=f8df19d9-b8ad-420b-8913-39e347f89f7f&amp;tw_document_href=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine&amp;tw_iframe_status=0&amp;tw_order_quantity=0&amp;tw_sale_amount=0&amp;txn_id=o48dy&amp;type=javascript&amp;version=2.3.29" style="display: none;" width="1"/>
#   <img height="1" src="https://analytics.twitter.com/i/adsct?bci=3&amp;eci=2&amp;event_id=50d961c3-9250-4220-81ba-37be457483e8&amp;events=%5B%5B%22pageview%22%2C%7B%7D%5D%5D&amp;integration=advertiser&amp;p_id=Twitter&amp;p_user_id=0&amp;pl_id=f8df19d9-b8ad-420b-8913-39e347f89f7f&amp;tw_document_href=https%3A%2F%2Fminibardelivery.com%2Fstore%2Fsearch%2Forganic%252Bwine%3Fq%3Dorganic%252520wine&amp;tw_iframe_status=0&amp;tw_order_quantity=0&amp;tw_sale_amount=0&amp;txn_id=o48dy&amp;type=javascript&amp;version=2.3.29" style="display: none;" width="1"/>
#  </body>
#  <b style="position: absolute; left: -1000px;">
#   <iframe style="display: none;">
#   </iframe>
#  </b>
# </html>

# %% [markdown]
# # 2. Scraping

# %%
name_list = []
price_list = []
delivery_time_list = []
for item in soup.findAll('li',class_='ProductTile_element__KRgs2'):
    
    #item title
    itemname = item.find('div',class_='ProductTileName_element__v8rIj').text
    name_list.append(itemname)
    
    #item price
    item_prices = item.find('div',class_="ProductTilePrice_element__RFvI_")
    item_price = item_prices.find('span',class_="ProductTilePrice_notDiscountSale__QG6dy").text
    price_list.append(item_price)

    #delivery time
    delivery_time = item.find('div',class_="DeliveryMethod_element__7MV6t").text
    delivery_time_list.append(delivery_time)
    
    #end
itemdf = pd.DataFrame({'Name': name_list,'Prices': price_list, "Deliverytime": delivery_time_list})

# %%
itemdf.to_csv("scrapingresult.csv")
